# %% [markdown]
# <a href="https://colab.research.google.com/github/samp3209/capstone/blob/main/Blip2_Logo_Captioning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#download model
import sys
if 'google.colab' in sys.modules:
    print('Running in Colab.')
    # !pip3 install transformers==4.15.0 timm==0.4.12 fairscale==0.4.4
    # !git clone https://github.com/salesforce/BLIP
    # %cd BLIP
# Out:
# Running in Colab.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers==4.15.0
#   Downloading transformers-4.15.0-py3-none-any.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 18.6 MB/s eta 0:00:00
# Collecting timm==0.4.12
#   Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 22.1 MB/s eta 0:00:00
# Collecting fairscale==0.4.4
#   Downloading fairscale-0.4.4.tar.gz (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.4/235.4 kB 6.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers==4.15.0) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers==4.15.0) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers==4.15.0) (2.27.1)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 73.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 28.5 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers==4.15.0) (2022.10.31)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers==4.15.0) (1.22.4)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 82.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers==4.15.0) (3.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers==4.15.0) (23.0)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.9/dist-packages (from timm==0.4.12) (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from timm==0.4.12) (0.15.1+cu118)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.15.0) (4.5.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.4->timm==0.4.12) (2.0.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.4->timm==0.4.12) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.4->timm==0.4.12) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.4->timm==0.4.12) (3.1.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.4->timm==0.4.12) (16.0.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.4->timm==0.4.12) (3.25.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.15.0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.15.0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.15.0) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.15.0) (2.0.12)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from sacremoses->transformers==4.15.0) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from sacremoses->transformers==4.15.0) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from sacremoses->transformers==4.15.0) (1.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->timm==0.4.12) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.4->timm==0.4.12) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.4->timm==0.4.12) (1.3.0)
# Building wheels for collected packages: fairscale, sacremoses
#   Building wheel for fairscale (pyproject.toml) ... done
#   Created wheel for fairscale: filename=fairscale-0.4.4-py3-none-any.whl size=292853 sha256=ba9d1ed86738f55c4fa4e255541b2f52d3a3b3899b3f239caa1c73905ea8a326
#   Stored in directory: /root/.cache/pip/wheels/71/88/74/ffb4fe1dd6799cbf410bab623fa7fc27fc3e1973a71a634a9d
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895259 sha256=4b9f27adc3ccc188948827052a337c0a6b1876a75f39329d08d8cd0b74424296
#   Stored in directory: /root/.cache/pip/wheels/12/1c/3d/46cf06718d63a32ff798a89594b61e7f345ab6b36d909ce033
# Successfully built fairscale sacremoses
# Installing collected packages: tokenizers, sacremoses, huggingface-hub, transformers, timm, fairscale
# Successfully installed fairscale-0.4.4 huggingface-hub-0.13.4 sacremoses-0.0.53 timm-0.4.12 tokenizers-0.10.3 transformers-4.15.0
# Cloning into 'BLIP'...
# remote: Enumerating objects: 274, done.
# remote: Total 274 (delta 0), reused 0 (delta 0), pack-reused 274
# Receiving objects: 100% (274/274), 7.16 MiB | 21.49 MiB/s, done.
# Resolving deltas: 100% (150/150), done.
# /content/BLIP

# %%
from PIL import Image
import requests
import torch
from torchvision import transforms
from torchvision.transforms.functional import InterpolationMode
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Blip Demo single image

# %%
#Demo image from blip
from PIL import Image
import requests
import torch
from torchvision import transforms
from torchvision.transforms.functional import InterpolationMode

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def load_demo_image(image_size,device):
    img_url = 'https://storage.googleapis.com/sfr-vision-language-research/BLIP/demo.jpg' 
    raw_image = Image.open(requests.get(img_url, stream=True).raw).convert('RGB')   

    w,h = raw_image.size
    display(raw_image.resize((w//5,h//5)))
    
    transform = transforms.Compose([
        transforms.Resize((image_size,image_size),interpolation=InterpolationMode.BICUBIC),
        transforms.ToTensor(),
        transforms.Normalize((0.48145466, 0.4578275, 0.40821073), (0.26862954, 0.26130258, 0.27577711))
        ]) 
    image = transform(raw_image).unsqueeze(0).to(device)   
    return image

# %%
#Demo image from blip
from models.blip import blip_decoder

image_size = 384
image = load_demo_image(image_size=image_size, device=device)

model_url = 'https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth'
    
model = blip_decoder(pretrained=model_url, image_size=image_size, vit='base')
model.eval()
model = model.to(device)

with torch.no_grad():
    # beam search
    caption = model.generate(image, sample=False, num_beams=3, max_length=20, min_length=5) 
    # nucleus sampling
    # caption = model.generate(image, sample=True, top_p=0.9, max_length=20, min_length=5) 
    print('caption: '+caption[0])
# Out:
# <PIL.Image.Image image mode=RGB size=409x273 at 0x7F6F72C8BDF0>
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# 100%|██████████| 1.97G/1.97G [00:11<00:00, 186MB/s]
# reshape position embedding from 196 to 576
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth
# caption: a woman and her dog on the beach

# %% [markdown]
# # Take images from google drive folder and caption them

# %%
#Link google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Define the path of the folder containing the images
folder_path = "/content/drive/MyDrive/beaverlogos/" 

# Create an empty list to store the file paths of the images
file_paths = []

# Loop through all the files in the folder
for filename in os.listdir(folder_path):
  # Check if the file is an image (ends with .jpg, .jpeg, or .png)
  if filename.endswith(('.jpg', '.jpeg', '.png')):
    # Get the file path of the image
    file_path = os.path.join(folder_path, filename)
    # Append the file path to the list
    file_paths.append(file_path)

# Print the file paths of the images
print(file_paths)
# Out:
# ['/content/drive/MyDrive/beaverlogos/a professionally designed chauncey logo, beaver, centered, cute, 4k hd, trending on artstation, chauncey, animated chauncey on all fours, icon, sym.png', '/content/drive/MyDrive/beaverlogos/animated college chauncey the beaver mascot in a green and blue color scheme. The background should be a mix of green and blue color.png', '/content/drive/MyDrive/beaverlogos/digital illustration, cute brown beaver, college beaver mascot, navy blue background, chauncey beaver and that it looks friendly and huggable, ring around chauncey.png', '/content/drive/MyDrive/beaverlogos/digital illustration, cute chauncey with long tail, college mascot with paws in the air, navy blue background, college beaver mascot looks friendyl.png', '/content/drive/MyDrive/beaverlogos/digital illustration, cute skinny chauncey the beaver running with rugby ball, college beaver mascot playing rugby, navy blue background,  beaver and that it looks friendly.png', '/content/drive/MyDrive/beaverlogos/digital illustration, cute chauncey the beaver standing, beaver college mascot playing rugby, navy blue background, beaver with rugby ball, high quality, .png', '/content/drive/MyDrive/beaverlogos/cute chauncey the beaver holding rugby ball, college mascot playing rugby, navy blue background,  beaver with rugby ball, high quality.png', '/content/drive/MyDrive/beaverlogos/digital illustration, cute chauncey wearing a large blue hat, college mascot standing with large hat, navy blue background,  beaver with large blue hat with brown trim, high quality.png', '/content/drive/MyDrive/beaverlogos/digital illustration, cute chauncey graduating, college mascot holding diploma, navy blue background,  chauncey with graduation cap and diploma .png', '/content/drive/MyDrive/beaverlogos/digital illustration, cute chauncey the beaver in the snow, adorable chauncey waving, college mascot, ski club, chauncey the beaver navy blue background,  chauncey happy.png', '/content/drive/MyDrive/beaverlogos/digital illustration, cute brown and white chauncey the beaver,  chauncey beaver skiing,college mascot, chauncey ski club, beaver, navy blue background,  beaver skiing.png', '/content/drive/MyDrive/beaverlogos/digital illustration, cute chauncey the beaver in snow globe, chauncey with reindeeer antlers, college mascot, festive chauncey, winter beaver, navy blue background.png', '/content/drive/MyDrive/beaverlogos/digital illustration, cute chauncey in a hockey shirt, chauncey skating, college mascot, hockey club, chauncey, navy blue background,  beaver skiing.png', '/content/drive/MyDrive/beaverlogos/digital illustration, cute chauncey the beaver in winter outfit, chauncey in the winter college mascot, ski club, cool chauncey the beaver, background,  chauncey the beaver in the winter forest.png', '/content/drive/MyDrive/beaverlogos/digital art, cute hd brown chauncey, college mascot, chauncey mascot, on a college campus, chauncey the beaver,mascot, 4k, detailed, vibrant color.png', '/content/drive/MyDrive/beaverlogos/chauncey beaver holding a white and blue rugby ball, chauncey the rugby beaver, holding rugby ball, blue background.png']

# %%
#opens image from path then stores to list as pil image
image_list = []
for path in file_paths:
  with Image.open(path).convert('RGB') as img:
      image_list.append(img)
      display(img.resize((200,200)))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F41D08537F0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F42903A3FD0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F41CC655CD0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F42911F9D60>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F42911F9C10>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F42903A3F70>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F4290408580>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F42903A3E80>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F42911F9D60>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F4290408580>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F41D08537F0>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F42903A3E80>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F42911F9D60>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F42911F9D60>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F41CC620490>
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F41CC620520>

# %%
#function for loading images and then transforming them to tensors for captioning
def load_images(raw_image):
  w,h = raw_image.size
  image_size = 512
  #display(raw_image.resize((w//5,h//5)))
    
  transform = transforms.Compose([
        transforms.Resize((image_size,image_size),interpolation=InterpolationMode.BICUBIC),
        transforms.ToTensor(),
        transforms.Normalize((0.48145466, 0.4578275, 0.40821073), (0.26862954, 0.26130258, 0.27577711))
        ]) 
  image = transform(raw_image).unsqueeze(0).to(device)   
  return image

# %%
#transforms inputs and stores them to list 
inputs = []
for image in image_list:
    x = load_images(image)
    inputs.append(x)

# %%
#blips through images in input and stores caption to a list
captions = []
from models.blip import blip_decoder

image_size = 512
for image in inputs:
      model_url = 'https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth'
      model = blip_decoder(pretrained=model_url, image_size=image_size, vit='base')
      model.eval()
      model = model.to(device)

      with torch.no_grad():
          # beam search
          caption = model.generate(image, sample=False, num_beams=3, max_length=20, min_length=5)
          # nucleus sampling
          # caption = model.generate(image, sample=True, top_p=0.9, max_length=20, min_length=5) 
          print('caption: '+caption[0])
          captions.append(caption)
# Out:
# reshape position embedding from 196 to 1024
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth
# caption: a squirrel sitting on a leaf
# reshape position embedding from 196 to 1024
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth
# caption: a brown bear wearing a green vest
# reshape position embedding from 196 to 1024
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth
# caption: a brown bear with a blue background
# reshape position embedding from 196 to 1024
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth
# caption: a cartoon beaver
# reshape position embedding from 196 to 1024
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth
# caption: a bear playing with a ball
# reshape position embedding from 196 to 1024
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth
# caption: a bear with a rugby ball
# reshape position embedding from 196 to 1024
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth
# caption: a beaver with a blue background
# reshape position embedding from 196 to 1024
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth
# caption: a beaver
# reshape position embedding from 196 to 1024
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth
# caption: a bear wearing a graduation cap
# reshape position embedding from 196 to 1024
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth
# caption: a bear on a snowy day
# reshape position embedding from 196 to 1024
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth
# caption: a squirrel on a snowboard
# reshape position embedding from 196 to 1024
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth
# caption: a bear on a snowboard
# reshape position embedding from 196 to 1024
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth
# caption: a teddy bear playing soccer
# reshape position embedding from 196 to 1024
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth
# caption: a bear in the snow
# reshape position embedding from 196 to 1024
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth
# caption: a capy capy capy capy capy capy capy cap
# reshape position embedding from 196 to 1024
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_capfilt_large.pth
# caption: a squirrel with a blue nose

# %%
#Prompts blip with questions about the image 
q1s = []
q2s = []
q3s = []
q4s = []
q5s = []
from models.blip_vqa import blip_vqa

image_size = 512
model_url = 'https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_vqa_capfilt_large.pth'
model = blip_vqa(pretrained=model_url, image_size=image_size, vit='base')
model.eval()
model = model.to(device)
for image in inputs:   
    question = 'what is the style of the image?'
    question2 = 'what are the colors predominant in the image?'
    question3 = 'what is the mood of the image?'
    question4 = 'what is the subject doing in this image?'
    question5 = 'where does this image take place?'
    with torch.no_grad():
        answer = model(image, question, train=False, inference='generate') 
        answer2 = model(image, question2, train=False, inference='generate') 
        answer3 = model(image, question3, train=False, inference='generate') 
        answer4 = model(image, question4, train=False, inference='generate') 
        answer5 = model(image, question5, train=False, inference='generate') 

        print('answer: '+answer[0])
        q1s.append(answer[0])
        q2s.append(answer2[0])
        q3s.append(answer3[0])
        q4s.append(answer4[0])
        q5s.append(answer5[0])
# Out:
# 100%|██████████| 1.35G/1.35G [01:03<00:00, 22.8MB/s]
# reshape position embedding from 900 to 1024
# load checkpoint from https://storage.googleapis.com/sfr-vision-language-research/BLIP/models/model_base_vqa_capfilt_large.pth
# answer: cartoon
# answer: cartoon
# answer: cartoon
# answer: cartoon
# answer: cartoon
# answer: cartoon
# answer: cartoon
# answer: cartoon
# answer: cartoon
# answer: cartoon
# answer: cartoon
# answer: cartoon
# answer: cartoon
# answer: cartoon
# answer: grumpy
# answer: cartoon

# %%
new_captions = []
for i in range(len(captions)):
  nc =  captions[i] + ',' + q1s[i] + ',' + q2s[i] + ',' + q3s[i] + ',' + q4s[i] + ',' + q5s[i] + '.png'
  new_captions.append(nc)

# %%
#matches the caption to the file path of the images to re name file to caption
path = '/content/drive/MyDrive/beaverlogos/'
for i in range(len(file_paths)):
  new_name = path + new_captions[i]
  old_name = file_paths[i]
  os.rename(old_name,new_name)

# %% [markdown]
# Congrats now you can train your images
